# %% [markdown]
# # Natural Language Toolkit 3.4

# %%
#!/usr/bin/python3

import nltk
from nltk.corpus import treebank


sentence = """At eight o'clock on Thursday morning
    Arthur didn't feel very good."""
tokens = nltk.word_tokenize(sentence)
print("TOKENS:\n", tokens)

tagged = nltk.pos_tag(tokens)
print("TAGGED\n:", tagged)

entities = nltk.chunk.ne_chunk(tagged)
print("ENTITIES:\n", entities)

t = treebank.parsed_sents('wsj_0001.mrg')[0]
t.draw()
# Out:
# TOKENS:
#  ['At', 'eight', "o'clock", 'on', 'Thursday', 'morning', 'Arthur', 'did', "n't", 'feel', 'very', 'good', '.']
# TAGGED
# : [('At', 'IN'), ('eight', 'CD'), ("o'clock", 'NN'), ('on', 'IN'), ('Thursday', 'NNP'), ('morning', 'NN'), ('Arthur', 'NNP'), ('did', 'VBD'), ("n't", 'RB'), ('feel', 'VB'), ('very', 'RB'), ('good', 'JJ'), ('.', '.')]
# ENTITIES:
#  (S
#   At/IN
#   eight/CD
#   o'clock/NN
#   on/IN
#   Thursday/NNP
#   morning/NN
#   (PERSON Arthur/NNP)
#   did/VBD
#   n't/RB
#   feel/VB
#   very/RB
#   good/JJ
#   ./.)

# %%
import os
os.system("clear")

def inputer():#asks user to enter input
    a=input("Stevie what are you doing today ?  ")
    b=a.split(",")#splits up input into list
    return b


def adderloop():#calls inputer to ask for input until = amount number of times
    amount=3
    x=0
    z=[]# makes an empty list to be filled
    while x<amount:#as long as x is less then amount
        enter=inputer()# call inputer
        e=enter#abbreviate inputer
        z.append(e)#add output of input to list z
        x=x+1 # keep the loop going
    return z

def line(b):
    todo=adderloop()
    for item in todo:
        print(item)
        
line(1)
# Out:
# Stevie what are you doing today ?  getting coffee
# Stevie what are you doing today ?  going to the gym
# Stevie what are you doing today ?  eating cake
# ['getting coffee']
# ['going to the gym']
# ['eating cake']
