# %%
import os
from urllib.request import build_opener
from lxml import html
os.chdir('/home/rendier/Ptolemy/Pharos/Commandow/RogueAI/fonts')
print(os.getcwd())
# Out:
# /home/rendier/Ptolemy/Pharos/Commandow/RogueAI/fonts

# %%
url = "https://bitbucket.org/libtcod/libtcod/src/380d86ed6188/data/fonts/"

opener = build_opener()
opener.addheaders = [("User-agent", "Mozilla/5.0 (X11; Linux x86_64)"), ("Accept", "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8"), ("Accept_encoding", "gzip, deflate, br"), ("Accept_language", "en-US,en;q=0.9"), ("Upgrade_insecure_requests", "1")]

# %%
file = opener.open(url)

# %%
print(file)

# %%
page = file.read()
print(page)
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n  <meta id="bb-bootstrap" data-current-user="{&quot;isKbdShortcutsEnabled&quot;: true, &quot;isSshEnabled&quot;: false, &quot;isAuthenticated&quot;: false}"\n />\n  <script nonce="O2tYi2BDyIotuLzN">\n\nif (window.performance) {\n\n  \n  window.performance.okayToSendMetrics = !document.hidden && \'onvisibilitychange\' in document;\n\n  if (window.performance.okayToSendMetrics) {\n\n    \n    window.addEventListener(\'visibilitychange\', function () {\n      if (document.hidden) {\n        window.performance.okayToSendMetrics = false;\n      }\n    });\n  }\n}\n</script>\n  \n  \n  <meta http-equiv="X-UA-Compatible" content="IE=edge" />\n  <meta name="viewport" content="width=device-width, initial-scale=1">\n  <meta charset="utf-8">\n  <title>\n  libtcod / libtcod \n  / source  / data  / fonts \n &mdash; Bitbucket\n</title>\n  <script nonce="O2tYi2BDyIotuLzN" type="text/javascript">(window.NREUM||(NREUM={})).loader_config={xpid:"VwMGVVZSGwII
# ...

# %%
root = html.fromstring(page)
images = root.xpath(".//a[contains(text(), '.png')]/text()")
print(len(images))
print(images[0])
# Out:
# 44
# arial10x10.png

# %%
down_url = "https://bitbucket.org/libtcod/libtcod/src/380d86ed61881430d56051d0bce6f10bc63c0b27/data/fonts/arial10x10.png"

# %%
for image in images:
    os.system(f"wget https://bitbucket.org/libtcod/libtcod/src/380d86ed61881430d56051d0bce6f10bc63c0b27/data/fonts/{image}")

# %% [markdown]
# ## Decimal Module

# %%
from decimal import *
getcontext()
getcontext().prec = 7
getcontext()
# Out:
# Context(prec=7, rounding=ROUND_HALF_EVEN, Emin=-999999, Emax=999999, capitals=1, clamp=0, flags=[], traps=[InvalidOperation, DivisionByZero, Overflow])

# %%
getcontext().prec = 28

# %%
Decimal(10)
# Out:
# Decimal('10')

# %%
Decimal('3.14')
# Out:
# Decimal('3.14')

# %%
Decimal(3.14)
# Out:
# Decimal('3.140000000000000124344978758017532527446746826171875')

# %%
Decimal((0, (3, 1, 4), -2))
# Out:
# Decimal('3.14')

# %%
Decimal((0, (3, 1, 4), -1))
# Out:
# Decimal('31.4')

# %%
Decimal(str(2.0 ** 0.5))
# Out:
# Decimal('1.4142135623730951')

# %%
Decimal(2) ** Decimal('0.5')
# Out:
# Decimal('1.414213562373095048801688724')

# %%
Decimal('NaN')
# Out:
# Decimal('NaN')

# %%
Decimal('-Infinity')
# Out:
# Decimal('-Infinity')

# %%
c = getcontext()
c.traps[FloatOperation] = True
Decimal(3.14)
# Out:
# ---------------------------------------------------------------------------
# FloatOperation                            Traceback (most recent call last)
# <ipython-input-20-50d354f0f8e7> in <module>()
#       1 c = getcontext()
#       2 c.traps[FloatOperation] = True
# ----> 3 Decimal(3.14)
#
# FloatOperation: [<class 'decimal.FloatOperation'>]

# %%
Decimal('3.5') < 3.7
# Out:
# ---------------------------------------------------------------------------
# FloatOperation                            Traceback (most recent call last)
# <ipython-input-21-4f820a39b13c> in <module>()
# ----> 1 Decimal('3.5') < 3.7
#
# FloatOperation: [<class 'decimal.FloatOperation'>]

# %%
Decimal('3.5') == 3.5
# Out:
# True

# %%
getcontext().prec = 6
Decimal('3.0')
# Out:
# Decimal('3.0')

# %%
Decimal('3.1415926535')
# Out:
# Decimal('3.1415926535')

# %%
Decimal('3.1415926535') + Decimal('2.7182818285')
# Out:
# Decimal('5.85987')

# %%
getcontext().rounding = ROUND_UP

# %%
getcontext()
# Out:
# Context(prec=6, rounding=ROUND_UP, Emin=-999999, Emax=999999, capitals=1, clamp=0, flags=[Inexact, FloatOperation, Rounded], traps=[InvalidOperation, DivisionByZero, FloatOperation, Overflow])

# %%
Decimal('3.1415926535') + Decimal('2.7182818285')
# Out:
# Decimal('5.85988')

# %%
Decimal("1e9999999999999999999")
# Out:
# ---------------------------------------------------------------------------
# InvalidOperation                          Traceback (most recent call last)
# <ipython-input-29-b251a6f0f3fd> in <module>()
# ----> 1 Decimal("1e9999999999999999999")
#
# InvalidOperation: [<class 'decimal.InvalidOperation'>]

# %%
data = list(map(Decimal, '1.34 1.87 3.45 2.35 1.00 0.03 9.25'.split()))

# %%
max(data)
# Out:
# Decimal('9.25')

# %%
min(data)
# Out:
# Decimal('0.03')

# %%
sorted(data)
# Out:
# [Decimal('0.03'),
#  Decimal('1.00'),
#  Decimal('1.34'),
#  Decimal('1.87'),
#  Decimal('2.35'),
#  Decimal('3.45'),
#  Decimal('9.25')]

# %%
sum(data)
# Out:
# Decimal('19.29')

# %%
a, b, c = data[:3]

# %%
str(a)
# Out:
# '1.34'

# %%
float(a)
# Out:
# 1.34

# %%
round(a, 1)
# Out:
# Decimal('1.4')

# %%
getcontext().rounding = ROUND_DOWN

# %%
round(a, 1)
# Out:
# Decimal('1.3')

# %%
round(a, 2)
# Out:
# Decimal('1.34')

# %%
int(a)
# Out:
# 1

# %%
a * 5
# Out:
# Decimal('6.70')

# %%
a * b
# Out:
# Decimal('2.5058')

# %%
c % a
# Out:
# Decimal('0.77')

# %%
getcontext().prec = 28

# %%
Decimal(2).sqrt()
# Out:
# Decimal('1.414213562373095048801688724')

# %%
Decimal(1).exp()
# Out:
# Decimal('2.718281828459045235360287471')

# %%
Decimal('10').ln()
# Out:
# Decimal('2.302585092994045684017991455')

# %%
Decimal('10').log10()
# Out:
# Decimal('1')

# %%
Decimal("7.325").quantize(Decimal('.01'), rounding=ROUND_DOWN)
# Out:
# Decimal('7.32')

# %%
Decimal("7.325").quantize(Decimal('1'), rounding=ROUND_DOWN)
# Out:
# Decimal('7')

# %%
Decimal("7.325").quantize(Decimal('1.'), rounding=ROUND_UP)
# Out:
# Decimal('8')

# %%
myothercontext = Context(prec=60, rounding=ROUND_HALF_DOWN)
setcontext(myothercontext)
Decimal(1) / Decimal(7)
# Out:
# Decimal('0.142857142857142857142857142857142857142857142857142857142857')

# %%
BasicContext
# Out:
# Context(prec=9, rounding=ROUND_HALF_UP, Emin=-999999, Emax=999999, capitals=1, clamp=0, flags=[], traps=[Clamped, InvalidOperation, DivisionByZero, Overflow, Underflow])

# %%
ExtendedContext
# Out:
# Context(prec=9, rounding=ROUND_HALF_EVEN, Emin=-999999, Emax=999999, capitals=1, clamp=0, flags=[], traps=[])

# %%
setcontext(ExtendedContext)

# %%
Decimal(1) / Decimal(7)
# Out:
# Decimal('0.142857143')

# %%
Decimal(42) / Decimal(0)
# Out:
# Decimal('Infinity')

# %%
setcontext(BasicContext)

# %%
Decimal(42) / Decimal(0)
# Out:
# ---------------------------------------------------------------------------
# DivisionByZero                            Traceback (most recent call last)
# <ipython-input-61-c91a456b856f> in <module>()
# ----> 1 Decimal(42) / Decimal(0)
#
# DivisionByZero: [<class 'decimal.DivisionByZero'>]

# %%
setcontext(ExtendedContext)
getcontext().clear_flags()

# %%
Decimal(355) / Decimal(113)
# Out:
# Decimal('3.14159292')

# %%
getcontext()
# Out:
# Context(prec=9, rounding=ROUND_HALF_EVEN, Emin=-999999, Emax=999999, capitals=1, clamp=0, flags=[Inexact, Rounded], traps=[])

# %%
setcontext(ExtendedContext)

# %%
Decimal(1) / Decimal(0)
# Out:
# Decimal('Infinity')

# %%
getcontext().traps[DivisionByZero] = 1

# %%
Decimal(1) / Decimal(0)
# Out:
# ---------------------------------------------------------------------------
# DivisionByZero                            Traceback (most recent call last)
# <ipython-input-68-1ae10108742b> in <module>()
# ----> 1 Decimal(1) / Decimal(0)
#
# DivisionByZero: [<class 'decimal.DivisionByZero'>]
